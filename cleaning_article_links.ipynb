# %%
import pandas as pd

# %%
df=pd.read_csv("main_labeled_data.txt",sep=" @ ")
df
# Out:
# C:\Users\2077a\AppData\Local\Temp\ipykernel_15356\874208027.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv("main_labeled_data.txt",sep=" @ ")
#                Distributer        bias  \
# 0         The Siasat Daily   Lean Left
# 1                 Latestly       Right
# 2        Financial Express  Lean Right
# 3              India Today  Lean Right
# 4            Tribune India  Lean Right
# ...                    ...         ...
# 16865         News Addicts   Far Right
# 16866  Longview Daily News      Center
# 16867     American Thinker   Far Right
# 16868                 WMUR      Center
# 16869           jurist.org   Lean Left
#
#                                              article_url
# 0      https://www.siasat.com/traffic-resumes-on-ramb...
# ...

# %%
df = df.drop_duplicates(keep='first')
df.reset_index(inplace=True)
df.drop(columns='index',inplace=True)
# Out:
# C:\Users\2077a\AppData\Local\Temp\ipykernel_15356\739093330.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns='index',inplace=True)

# %%
df.shape
# Out:
# (9094, 3)

# %%
df.bias.replace(to_replace=["Lean Left","Far Left"], value="Left", inplace=True)
df.bias.replace(to_replace=["Lean Right","Far Right"], value="Right", inplace=True)
# Out:
# C:\Users\2077a\AppData\Local\Temp\ipykernel_15356\632862047.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.bias.replace(to_replace=["Lean Left","Far Left"], value="Left", inplace=True)
# C:\Users\2077a\AppData\Local\Temp\ipykernel_15356\632862047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.bias.value_counts()
# Out:
# bias
# Left      3094
# Center    3030
# Right     2970
# Name: count, dtype: int64

# %%
df.to_csv("scrape_main_data.txt",sep="@")
